# %%
import os
import numpy as np
import pandas as pd
import random

# %%
HOME_DIR = "/scratch/s223669184/project_data/Grant25/"

# %%
/scratch/s223669184/project_data/Grant25/TimeSeriesECM/infer_results/long_term_forecast_ETTh1_96_96_TimeMixer_ETTh1_ftM_sl96_ll0_pl96_dm16_nh8_el2_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_0/metrics-96-0.0.txt
/scratch/s223669184/project_data/Grant25/TimeSeriesECM/infer_results/long_term_forecast_ETTh1_96_96_TimeMixer_ETTh1_ftM_sl96_ll0_pl96_dm16_nh8_el2_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_0/metrics-96-0.1.txt


/scratch/s223669184/project_data/Grant25/TimeSeriesECM/infer_results/long_term_forecast_ETTh1_96_96_TimeMixer_ETTh1_ftM_sl96_ll0_pl96_dm16_nh8_el2_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_0/metrics.npy
